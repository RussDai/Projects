# %% [markdown]
# # **Olympic Dataset Analysis:**

# %% [markdown]
# This dataset provides an opportunity to ask questions about how the Olympics have evolved over time, including questions about the participation and performance of women, different nations, and different sports and events.

# %% [markdown]
# 1. `ID` - Unique number for each athlete
#
# 2. `Name` - Athlete's name
#
# 3. `Sex` - M or F
#
# 4. `Age` - Integer
#
# 5. `Height` - In centimeters
#
# 6. `Weight` - In kilograms
#
# 7. `Team` - Team name
#
# 8. `NOC` - National Olympic Committee 3-letter code
#
# 9. `Games` - Year and season
#
# 10. `Year` - Integer
#
# 11. `Season` - Summer or Winter
#
# 12. `City` - Host city
#
# 13. `Sport` - Sport
#
# 14. `Event` - Event
#
# 15. `Medal` - `Gold`, `Silver`, `Bronze`, or `NA`

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("C:/Users/MyMachine/Desktop/Mission-Project/00_DataSets/16_athlete_events.csv")

# %%
data.shape
# Out:
# (271116, 15)

# %%
# Display top 5 rows of the dataset:
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# ---
# ----

# %%
# last 5 rows of the dataset:
data.tail(5)
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %% [markdown]
# ----
# ----

# %%
# Print 5 random samples from the dataset:
data.sample(5)
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 249887  125147                Pter Istvn Vnky   M  20.0   190.0    83.0
# 130563   65735                    Petr Lacina   M  22.0   184.0    85.0
# 242911  121650                 Trn Th Ngc Anh   F  22.0   161.0    52.0
# 251163  125779  Sofiya Aleksandrovna Velikaya   F  27.0   175.0    70.0
# 68297    34885          Teresa Fernndez Surez   F  42.0     NaN     NaN
#
#                   Team  NOC        Games  Year  Season       City      Sport  \
# 249887          Sweden  SWE  1988 Summer  1988  Summer      Seoul    Fencing
# 130563  Czech Republic  CZE  1996 Summer  1996  Summer    Atlanta       Judo
# 242911         Vietnam  VIE  1980 Summer  1980  Summer     Moskva  Athletics
# 251163          Russia  RUS  2012 Summer  2012  Summer     London    Fencing
# 68297            Spain  ESP  1992 Summer  1992  Summer  Barcelona    Archery
#
#                                     Event   Medal
# ...

# %% [markdown]
# ----
# ----

# %%
# Shape of the dataset:
print(data.shape)
print(F"Number of Rows: {data.shape[0]}")
print(F"Number of Columns: {data.shape[1]}")
# Out:
# (271116, 15)
# Number of Rows: 271116
# Number of Columns: 15

# %% [markdown]
# ---
# ---

# %%
# Check for null values in the dataset:
data.isnull().any()
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# We are going to fill missing values in `Age`, `Height` and `Weight` columns and not on `Medal` column because, Null value in this column  means `No medal`.

# %%
data["Age"].fillna(data["Age"].mean(), inplace= True)
# Out:
# C:\Users\MyMachine\AppData\Local\Temp\ipykernel_10416\3999490818.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Age"].fillna(data["Age"].mean(), inplace= True)

# %%
data["Age"].isnull().any()
# Out:
# np.False_

# %%
data["Height"]= data["Height"].fillna(data["Height"].mean())
data["Height"].isnull().any()
# Out:
# np.False_

# %%
data["Weight"]= data["Weight"].fillna(data["Weight"].mean())
data["Weight"].isnull().any()
# Out:
# np.False_

# %%
data.isnull().any().sum()
# Out:
# np.int64(1)

# %% [markdown]
# ----
# ----

# %%
# Get general info of the dataset:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     271116 non-null  float64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# ----
# ----

# %%
# Get overall statistics about the dataset:
data.describe()
# Out:
#                   ID            Age        Height         Weight  \
# count  271116.000000  271116.000000  271116.00000  271116.000000
# mean    68248.954396      25.556898     175.33897      70.702393
# std     39022.286345       6.280857       9.27810      12.574690
# min         1.000000      10.000000     127.00000      25.000000
# 25%     34643.000000      22.000000     170.00000      63.000000
# 50%     68205.000000      25.000000     175.33897      70.702393
# 75%    102097.250000      28.000000     180.00000      75.000000
# max    135571.000000      97.000000     226.00000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.describe(include= "all")
# Out:
#                    ID                  Name     Sex            Age  \
# count   271116.000000                271116  271116  271116.000000
# unique            NaN                134732       2            NaN
# top               NaN  Robert Tait McKenzie       M            NaN
# freq              NaN                    58  196594            NaN
# mean     68248.954396                   NaN     NaN      25.556898
# std      39022.286345                   NaN     NaN       6.280857
# min          1.000000                   NaN     NaN      10.000000
# 25%      34643.000000                   NaN     NaN      22.000000
# 50%      68205.000000                   NaN     NaN      25.000000
# 75%     102097.250000                   NaN     NaN      28.000000
# max     135571.000000                   NaN     NaN      97.000000
#
#               Height         Weight           Team     NOC        Games  \
# count   271116.00000  271116.000000         271116  271116       271116
# ...

# %% [markdown]
# ---
# ----

# %%
# Check for duplicate Rows:
data.duplicated().any()
# Out:
# np.True_

# %%
data.duplicated().sum()
# Out:
# np.int64(1385)

# %%
data[data.duplicated()]
# Out:
#             ID                                 Name Sex   Age     Height  \
# 1252       704                   Dsir Antoine Acket   M  27.0  175.33897
# 4282      2449               William Truman Aldrich   M  48.0  175.33897
# 4283      2449               William Truman Aldrich   M  48.0  175.33897
# 4862      2777               Hermann Reinhard Alker   M  43.0  175.33897
# 4864      2777               Hermann Reinhard Alker   M  43.0  175.33897
# ...        ...                                  ...  ..   ...        ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  175.33897
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  175.33897
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  175.33897
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0  175.33897
# 270200  135173                     Henri Achille Zo   M  58.0  175.33897
#
#            Weight           Team  NOC        Games  Year  Season         City  \
# ...

# %%
# Drop duplicate data:
data= data.drop_duplicates()

# %%
data.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# ----
# ----

# %%
# Correlation analysis:
numeric_data= data.select_dtypes(include= "number")
numeric_data.head()
# Out:
#    ID   Age     Height     Weight  Year
# 0   1  24.0  180.00000  80.000000  1992
# 1   2  23.0  170.00000  60.000000  2012
# 2   3  24.0  175.33897  70.702393  1920
# 3   4  34.0  175.33897  70.702393  1900
# 4   5  21.0  185.00000  82.000000  1988

# %%
numeric_data.corr()
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.002825 -0.009791 -0.008059  0.011381
# Age    -0.002825  1.000000  0.111115  0.168071 -0.088250
# Height -0.009791  0.111115  1.000000  0.786635  0.030126
# Weight -0.008059  0.168071  0.786635  1.000000  0.011598
# Year    0.011381 -0.088250  0.030126  0.011598  1.000000

# %%
plt.figure(figsize= (15, 6))
sns.heatmap(data= numeric_data.corr(), annot=True, cmap='coolwarm', square=True)
# Out:
# <Axes: >

# %% [markdown]
# ----
# -----
# -----
# ----

# %%
# Distribution of Athletes by Gender (Sex):
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data["Sex"].value_counts()
# Out:
# Sex
# M    195353
# F     74378
# Name: count, dtype: int64

# %%
sns.countplot(data= data, x= "Sex", palette= 'Blues', hue= "Sex", legend= False)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
data_cat= data["Sex"].value_counts()

# %%
# Access the indexes from data_cat
data_cat.index
# Out:
# Index(['M', 'F'], dtype='object', name='Sex')

# %%
# Access actual values from this data_cat:
data_cat.values
# Out:
# array([195353,  74378])

# %%
# Plot Barplot: 
sns.barplot(x= data_cat.index, y= data_cat.values)
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# ---
# ---

# %%
# Display thee top 10 most popular sports 
# based on the athlete partipation:
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
top_10= data["Sport"].value_counts().head(10)

# %%
top_10
# Out:
# Sport
# Athletics               38624
# Gymnastics              26707
# Swimming                23195
# Shooting                11448
# Cycling                 10827
# Fencing                 10735
# Rowing                  10595
# Cross Country Skiing     9133
# Alpine Skiing            8829
# Wrestling                7154
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))

sns.barplot(y= top_10.index, x= top_10.values, palette= 'Blues', hue= top_10.values)
# Out:
# <Axes: ylabel='Sport'>

# %%
data["Sport"].value_counts().head(10).plot(kind= "pie", autopct= "%1.1f%%", title= "Top 10 Sports")
plt.ylabel("")
plt.show()

# %% [markdown]
# ---
# ---

# %%
# Find the most popular sport based 
# on athlete participation:
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data["Sport"].value_counts().sort_values(ascending=False).index[0]
# Out:
# 'Athletics'

# %%
# Or; 
data["Sport"].value_counts().idxmax()
# Out:
# 'Athletics'

# %% [markdown]
# ----
# ----

# %%
# Check the distribution of age: 
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data["Age"].plot(kind= "hist", bins= 50, title="Age Distribution")
# Out:
# <Axes: title={'center': 'Age Distribution'}, ylabel='Frequency'>

# %%
# OR; 
sns.displot(data= data, x= "Age", kde= True, kind= "hist")

# %%
sns.histplot(data= data, x= 'Age', bins= 40, kde= True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# Box plot of Age Column: 
data["Age"].plot(kind= "box", title="Age Distribution")
# Out:
# <Axes: title={'center': 'Age Distribution'}>

# %%
sns.boxplot(data["Age"], orient= "h")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxenplot(data["Age"], orient= "h")
# Out:
# <Axes: xlabel='Age'>

# %%
data["Age"].min()
# Out:
# np.float64(10.0)

# %%
data["Age"].max()
# Out:
# np.float64(97.0)

# %%
data["Age"].mean()
# Out:
# np.float64(25.458302932173996)

# %%
# Skewness: 
data["Age"].skew()
# Out:
# np.float64(1.5877141959478527)

# %%
# Kurtosis: 
data["Age"].kurt()
# Out:
# np.float64(5.462670605644467)

# %%
# Kurtosis: 
data["Age"].kurtosis()
# Out:
# np.float64(5.462670605644467)

# %% [markdown]
# -----
# ---
# ---

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
# Scatter plot between Age and Height:
sns.scatterplot(data= data, x= "Age", y= "Height")
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.scatterplot(data= data, x= "Age", y= "Height", hue= "Sex")
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
# Age distribution by Medal Type:
sns.barplot(data= data, x= "Age", y= "Medal", palette= "viridis")
# Out:
# C:\Users\MyMachine\AppData\Local\Temp\ipykernel_10416\88860662.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= data, x= "Age", y= "Medal", palette= "viridis")
# <Axes: xlabel='Age', ylabel='Medal'>

# %%
sns.boxplot(data= data, x= "Medal", y= "Age", palette= "Set2", hue= "Medal", legend= False)
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %%
sns.boxenplot(data= data, x= "Medal", y= "Age", palette= "Set2", hue= "Medal", legend= False)
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %%
sns.boxplot(data= data, x= "Medal", y= "Age", palette= "Set2", hue= "Sex")
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %%
sns.boxenplot(data= data, x= "Medal", y= "Age", palette= "Set2", hue= "Sex")
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %% [markdown]
# ----
# ----
# ---

# %%
# How many Gold , Silver and Bronze medals
#  have been awarded to male and female 
# athletes:
pd.crosstab(data["Sex"], data["Medal"])
# Out:
# Medal  Bronze  Gold  Silver
# Sex
# F        3771  3747    3735
# M        9524  9622    9373

# %%
sns.heatmap(pd.crosstab(data["Sex"], data["Medal"]), annot=True, cmap= "Blues")
# Out:
# <Axes: xlabel='Medal', ylabel='Sex'>

# %% [markdown]
# ---
# ---

# %%
# Display medal performance for a 
# specific country per year:
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df_india= data[data["Team"]== "India"]

# %%
india_medal= df_india.groupby(by= "Year")["Medal"].count()

# %%
india_medal
# Out:
# Year
# 1900     2
# 1920     0
# 1924     7
# 1928    14
# 1932    15
# 1936    19
# 1948    20
# 1952    15
# 1956    17
# 1960    13
# 1964    15
# 1968    16
# 1972    14
# 1976     0
# 1980    16
# 1984     0
# 1988     0
# 1992     0
# 1996     1
# 1998     0
# 2000     1
# 2002     0
# 2004     1
# 2006     0
# 2008     3
# 2010     0
# 2012     6
# 2014     0
# 2016     2
# Name: Medal, dtype: int64

# %%
sns.lineplot(india_medal)
# Out:
# <Axes: xlabel='Year', ylabel='Medal'>

# %% [markdown]
# ---
# ---

# %%
# Display the top 10 atheletes by medal won:
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
medal_counts= data["Name"].value_counts().reset_index()

# %%
medal_counts.columns= ["Athlete Name", "Medal Count"]

# %%
medal_counts
# Out:
#                       Athlete Name  Medal Count
# 0         Heikki Ilmari Savolainen           39
# 1            Joseph "Josy" Stoffel           38
# 2              Ioannis Theofilakis           36
# 3                      Takashi Ono           33
# 4                   Andreas Wecker           32
# ...                            ...          ...
# 134727                  Andrzej ya            1
# 134728      Olga Igorevna Zyuzkova            1
# 134729  James Francis "Jim" Zylker            1
# 134730      Yury Ivanovich Zyabrev            1
# 134731  Victor Andrew "Vic" Zwolak            1
#
# [134732 rows x 2 columns]

# %%
sns.barplot(x= "Medal Count", y= "Athlete Name", data= medal_counts.head(10), palette= "Blues_d", hue= "Athlete Name", legend= False)
# Out:
# <Axes: xlabel='Medal Count', ylabel='Athlete Name'>

# %% [markdown]
# ---
# ---

# %%
# Find and display the count of medals 
# (Bronze, Silver, Gold) won in each 
# city and, present the result in a 
# tabular format:
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.groupby(by= ["City", "Medal"]).size()
# Out:
# City         Medal
# Albertville  Bronze    106
#              Gold      104
#              Silver    108
# Amsterdam    Bronze    250
#              Gold      245
#                       ...
# Torino       Gold      176
#              Silver    175
# Vancouver    Bronze    171
#              Gold      174
#              Silver    175
# Length: 126, dtype: int64

# %%
data.groupby(by= ["City", "Medal"]).size().unstack()
# Out:
# Medal                   Bronze  Gold  Silver
# City
# Albertville                106   104     108
# Amsterdam                  250   245     239
# Antwerpen                  367   493     448
# Athina                     860   883     859
# Atlanta                    629   608     605
# Barcelona                  604   559     549
# Beijing                    710   671     667
# Berlin                     295   312     310
# Calgary                     88    87      88
# Chamonix                    37    55      38
# Cortina d'Ampezzo           50    51      49
# Garmisch-Partenkirchen      35    36      37
# Grenoble                    63    66      70
# Helsinki                   300   306     291
# Innsbruck                  128   131     138
# Lake Placid                101   104     105
# Lillehammer                112   110     109
# London                    1214  1215    1195
# Los Angeles                706   726     691
# Melbourne                  286   290     281
# ...

# %% [markdown]
# ---
# ----
# ---

# %%
# Sort the medal counts per city based on 
# the total number of medals
# (Bronze, Silver, Gold):
medal_count= data.groupby(by= ["City", "Medal"]).size().unstack()

# %%
medal_count["Total"]= medal_count[["Bronze", "Silver", "Gold"]].sum(axis= 1)

# %%
medal_count.sort_values(by= "Total", ascending= False)
# Out:
# Medal                   Bronze  Gold  Silver  Total
# City
# London                    1214  1215    1195   3624
# Athina                     860   883     859   2602
# Los Angeles                706   726     691   2123
# Beijing                    710   671     667   2048
# Rio de Janeiro             703   665     655   2023
# Sydney                     680   663     661   2004
# Atlanta                    629   608     605   1842
# Barcelona                  604   559     549   1712
# Seoul                      549   520     513   1582
# Paris                      449   475     501   1425
# Moskva                     469   457     458   1384
# Montreal                   448   438     434   1320
# Antwerpen                  367   493     448   1308
# Munich                     419   404     392   1215
# Mexico City                358   359     340   1057
# Tokyo                      343   347     339   1029
# Stockholm                  312   338     327    977
# ...
