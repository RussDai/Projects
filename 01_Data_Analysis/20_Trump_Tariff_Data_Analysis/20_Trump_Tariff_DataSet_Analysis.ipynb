# %% [markdown]
# # **Trump Tariff DataSet Analysis:**

# %% [markdown]
# **Source:** __https://www.kaggle.com/datasets/mesumraza/trump-tarrif-data__

# %%
import pandas as pd 
pd.read_excel("C:/Users/MyMachine/Desktop/Mission-Project/00_DataSets/20_Trump_Tariff_Data_1.xlsx")
# Out:
#                               Country  US 2024 Deficit  US 2024 Exports  \
# 0                         Afghanistan            -11.1             11.4
# 1                             Albania             13.4            141.7
# 2                             Algeria          -1447.1           1014.5
# 3                             Andorra              1.5              4.9
# 4                              Angola          -1186.9            682.4
# ..                                ...              ...              ...
# 199                           Vietnam        -123463.0          13098.2
# 200  West Bank Administered by Israel             -2.3              3.7
# 201                             Yemen            125.2            134.1
# 202                            Zambia            -55.3            113.8
# 203                          Zimbabwe            -24.1             43.8
#
#      US 2024 Imports (Customs Basis)  Trump Tariffs Alleged  Trump Response  \
# ...
